# %%
# %load_ext autoreload
# %autoreload 0

# %%
# %autoreload

# %%
import sys
sys.path.append('/pollard/home/bsmith/Projects/haplo-benchmark/include/StrainFacts')

# %%
import xarray as xr
import sqlite3
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
import torch
import pyro
import scipy as sp

import lib.plot
from scipy.spatial.distance import pdist, squareform
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.cluster import AgglomerativeClustering
from lib.pandas_util import idxwhere

import sfacts as sf

from tqdm import tqdm

# from lib.project_style import color_palette, major_allele_frequency_bins
# from lib.project_data import metagenotype_db_to_xarray
# from lib.plot import ordination_plot, mds_ordination, nmds_ordination
# import lib.plot
# from lib.plot import construct_ordered_pallete
# from lib.pandas_util import idxwhere

# %%
# !ls  data/zshi.sp-102556.metagenotype.filt-poly05-cvrg25.nc
# Out:
# data/zshi.sp-102556.metagenotype.filt-poly05-cvrg25.nc

# %%
mgen = sf.data.Metagenotypes.load('data/zshi.sp-102556.metagenotype.nc')
# Out:
# /pollard/home/bsmith/Projects/StrainFacts/sfacts/data.py:191: UserWarning: Converting 'library_id' dimension to 'sample'.
#   warn("Converting 'library_id' dimension to 'sample'.")
# /pollard/home/bsmith/Projects/StrainFacts/sfacts/data.py:194: UserWarning: Dropping 'species_id' from dims.
#   warn("Dropping 'species_id' from dims.")

# %%
print(mgen.sizes)
print(mgen.select_samples_with_coverage(0.05).sizes)
# Out:
# Frozen({'sample': 17989, 'position': 99774, 'allele': 2})
# Frozen({'sample': 3580, 'position': 99774, 'allele': 2})

# %%
print(mgen.select_samples_with_coverage(0.25).sizes)
# Out:
# Frozen({'sample': 2527, 'position': 99774, 'allele': 2})

# %%
x = mgen.data

(x.sum("allele") > 0).mean("position") > 0.05
# Out:
# <xarray.DataArray 'tally' (sample: 3579)>
# array([ True,  True,  True, ...,  True,  True,  True])
# Coordinates:
#   * sample      (sample) object 'ERR1018187' 'ERR1018225' ... 'SRR7658690'
#     species_id  int64 102556

# %%
(x.sum("allele") > 0).mean("position")
# Out:
# <xarray.DataArray 'tally' (sample: 3579)>
# array([0.89763762, 0.89921977, 0.92147811, ..., 0.45604681, 0.2618769 ,
#        0.92338535])
# Coordinates:
#   * sample      (sample) object 'ERR1018187' 'ERR1018225' ... 'SRR7658690'
#     species_id  int64 102556

# %%
(x.sum("allele") > 0).mean("position").min()# > 0.05).sum()
# Out:
# <xarray.DataArray 'tally' ()>
# array(0.05017339)
# Coordinates:
#     species_id  int64 102556
